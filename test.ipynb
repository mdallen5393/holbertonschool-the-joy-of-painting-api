# %%
import pandas as pd
import ast
import mysql.connector

# Database connection settings
db_config = {
    "host": "localhost",
    "user": "root",
    "password": "root",
    "database": "tjopdb",
}

conn = mysql.connector.connect(**db_config)
cursor = conn.cursor()

# %% [markdown]
# ## Colors Table
#
# 1. Retrieve and sanitize colors

# %%
csv_file_path = "data/The Joy Of Painiting - Colors Used"
df = pd.read_csv(csv_file_path)

# Create an empty dictionary to store the color-hex mappings
color_dict = {}

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    colors_list = ast.literal_eval(row['colors'])
    hex_list = ast.literal_eval(row['color_hex'])

    cleaned_colors_list = [color.replace('\r', '').replace('\n', '').lower() for color in colors_list]

    # Add each color-hex pair to the dictionary
    for color, hex_code in zip(cleaned_colors_list, hex_list):
        color_dict[color] = hex_code

# Print the dictionary
# print(color_dict)

# %% [markdown]
# 2. Connect to database and store colors in colors table

# %%
for key, val in color_dict.items():
    insert_query = f"""
        INSERT IGNORE INTO Colors (name, hex)
        VALUES ('{key.lower()}', '{val}')
    """
    cursor.execute(insert_query)

conn.commit()


print("CSV data has been transferred to the MySQL database.")
# Out:
# CSV data has been transferred to the MySQL database.

# %% [markdown]
# ## Episodes Table
#
# 1. Retrieve and sanitize episode information
#
# *Note that the following code uses the unsafe assumption that the files are in order and that the rows in each file correspond to each other.  The "safe" code is also provided, which outputs any mismatching rows and leaves blanks in the date field where rows are mismatched*

# %%
from datetime import datetime

file_path = "data/The Joy Of Painting - Episode Dates"

# date_dict = {} # SAFE
date_list = [] # UNSAFE
with open(file_path, "r") as file:
    line = file.readline()
    while line:
        # Do stuff with the line
        start_quote = line.find('"') + 1
        end_quote = line.find('"', start_quote)

        # title = line[start_quote:end_quote].lower()
        title = line[start_quote:end_quote]

        start_date = line.find('(', end_quote) + 1
        end_date = line.find(')', start_date)

        date = line[start_date:end_date]

        date_object = datetime.strptime(date, "%B %d, %Y")
        formatted_date = date_object.strftime("%Y-%m-%d")
        # SAFE: Use this to be more
        # date_dict[title] = formatted_date
        # UNSAFE: Used because we know the files are in order and correspond to
        # each other.
        date_list.append(formatted_date)

        line = file.readline()

# FOR TESTING
# print("Date Dict:")
# for key, val in date_dict.items():
#     print(f'{key}: {val}')
# print("\n\n")

# Convert the painting titles in the DataFrame to lowercase and remove leading/trailing spaces
# df['painting_title'] = df['painting_title'].str.strip().str.lower()
df['painting_title'] = df['painting_title'].str.strip()

mismatch = {}

# Populate the air_date column using the cleaned painting titles
for index, row in df.iterrows():
    painting_title = row['painting_title']
    # SAFE
    # if painting_title in date_dict:
        # df.at[index, 'air_date'] = date_dict[painting_title]
    # else:
    #     print(f"Missing date for painting: {painting_title}")
    df.at[index, 'air_date'] = date_list[index] # UNSAFE

# Remove unwanted columns from df
desired_columns = ['painting_title', 'season', 'episode', 'youtube_src', 'air_date', 'img_src']
episodes_df = df.loc[:, desired_columns].copy()

# FOR USE LATER
desired_columns = ['painting_title', 'colors']
pc_df = df.loc[:, desired_columns].copy()


# Print the updated DataFrame
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
df_head = episodes_df.head(5)
df_head
# Out:
#         painting_title  season  episode  \
# 0  A Walk in the Woods       1        1
# 1         Mt. McKinley       1        2
# 2         Ebony Sunset       1        3
# 3          Winter Mist       1        4
# 4         Quiet Stream       1        5
#
#                                  youtube_src    air_date  \
# 0  https://www.youtube.com/embed/oh5p5f5_-7A  1983-01-11
# 1  https://www.youtube.com/embed/RInDWhYceLU  1983-01-11
# 2  https://www.youtube.com/embed/UOziR7PoVco  1983-01-18
# 3  https://www.youtube.com/embed/0pwoixRikn4  1983-01-25
# 4  https://www.youtube.com/embed/DFSIQNjKRfk  1983-02-01
#
#                                              img_src
# 0  https://www.twoinchbrush.com/images/painting28...
# 1  https://www.twoinchbrush.com/images/painting28...
# 2  https://www.twoinchbrush.com/images/painting28...
# 3  https://www.twoinchbrush.com/images/painting28...
# 4  https://www.twoinchbrush.com/images/painting28...

# %% [markdown]
# 2. Connect to database and store episodes in episodes table.

# %%
insert_query = f"""
    INSERT INTO Episodes (title, season, episode, youtube_src, air_date, img_src)
    VALUES (%s, %s, %s, %s, %s, %s)
"""

for row in episodes_df.itertuples(index=False):
    cursor.execute(insert_query, row)
    episode_id = cursor.lastrowid

conn.commit()

print("CSV data has been transferred to the MySQL database.")
# Out:
# CSV data has been transferred to the MySQL database.

# %% [markdown]
# ## Subjects Table
#
# 1. Retrieve and sanitize Subject information

# %%
csv_file_path = "data/The Joy Of Painiting - Subject Matter"
subjects_df = pd.read_csv(csv_file_path)

subjects_df.columns = subjects_df.columns.str.strip()

id_vars = ['EPISODE', 'TITLE']
value_vars = subjects_df.columns[2:]

subjects_df = pd.melt(subjects_df, id_vars=id_vars, value_vars=value_vars, var_name='SUBJECT', value_name='VALUE')
subjects_df = subjects_df[subjects_df['VALUE'] == 1]
subjects_df = subjects_df.drop(columns=['VALUE', 'EPISODE'])
subjects_df['TITLE'] = subjects_df['TITLE'].str.strip('"')
subjects_df = subjects_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)


episodes_df['painting_title'] = episodes_df['painting_title'].str.lower()
episodes_df.head()

subjects_df = pd.merge(episodes_df, subjects_df, left_on='painting_title', right_on='TITLE', how='inner')
subjects_df = subjects_df[['painting_title', 'SUBJECT']]

# NEW
current_title = ''
title_counter = 0

# Iterate over the rows of the DataFrame
for index, row in subjects_df.iterrows():
    if row['painting_title'] != current_title:
        title_counter += 1
        current_title = row['painting_title']
    subjects_df.at[index, 'title_number'] = title_counter

# Remove the original 'painting_title' column if needed
subjects_df = subjects_df.drop(columns='painting_title')
# Convert the 'title_number' column to integer data type
subjects_df['title_number'] = subjects_df['title_number'].astype(int)

# Rename columns
subjects_df = subjects_df.rename(columns={'SUBJECT': 'subject_name', 'title_number': 'episode_id'})
subjects_df = subjects_df[['episode_id', 'subject_name']]
# END OF NEW

subjects_df.head()
# Out:
#    episode_id subject_name
# 0           1       bushes
# 1           1    deciduous
# 2           1        grass
# 3           1        river
# 4           1         tree

# %% [markdown]
# 2. Add data to Subjects table in database

# %%
# Remove duplicate entries from the dataframe
subjects_df = subjects_df.drop_duplicates(subset=['episode_id', 'subject_name'])

# Prepare the SQL statement for inserting data into the Subjects table
sql = "INSERT INTO Subjects (episode_id, subject_name) VALUES (%s, %s)"

# Convert the DataFrame to a list of tuples
values = subjects_df.to_records(index=False).tolist()

# Execute the SQL statement to insert the data into the Subjects table
cursor.executemany(sql, values)

# Commit the changes to the database
conn.commit()

# %% [markdown]
# ## PaintingColors Table

# %%
from ast import literal_eval

# Assuming you have the 'pc_df' DataFrame with the 'colors' column containing list-like strings

# Convert string representations of lists to actual lists
pc_df['colors'] = pc_df['colors'].apply(lambda x: literal_eval(x) if pd.notna(x) else x)

# Remove \n and \r from the 'colors' column (if any)
pc_df['colors'] = pc_df['colors'].apply(lambda x: [color.replace('\n', '').replace('\r', '') for color in x] if isinstance(x, list) else x)

# Explode the DataFrame and overwrite the original
pc_df = pc_df.explode('colors')


# replace names with ids
# Create a mapping of unique values in 'painting_title' to integers
mapping = {title: i + 1 for i, title in enumerate(pc_df['painting_title'].unique())}

# Replace values in 'painting_title' with their corresponding integers
pc_df['painting_title'] = pc_df['painting_title'].replace(mapping)

# Reorder columns if needed (optional step)
pc_df = pc_df[['painting_title', 'colors']]
pc_df.rename(columns={'painting_title': 'episode_id', 'colors': 'color_name'}, inplace=True)

# Remove duplicate entries from the dataframe
pc_df = pc_df.drop_duplicates(subset=['episode_id', 'color_name'])
pc_df['color_name'] = pc_df['color_name'].str.lower()

# Print the DataFrame
print(pc_df)
# Out:
#      episode_id        color_name
# 0             1  alizarin crimson
# 0             1        bright red
# 0             1    cadmium yellow
# 0             1     phthalo green
# 0             1     prussian blue
# 0             1         sap green
# 0             1    titanium white
# 0             1    van dyke brown
# 1             2  alizarin crimson
# 1             2        bright red
# 1             2    cadmium yellow
# 1             2     phthalo green
# 1             2     prussian blue
# 1             2         sap green
# 1             2    titanium white
# 1             2    van dyke brown
# 2             3  alizarin crimson
# 2             3       black gesso
# 2             3        bright red
# 2             3    cadmium yellow
# 2             3     phthalo green
# 2             3     prussian blue
# 2             3         sap green
# 2             3    titanium white
# 2             3    van dyke brown
# 3             4     prussian blue
# 3             4    titanium white
# 3             4    van dyke brown
# 4             5  alizarin crimson
# 4             5        bright red
# 4             5    cadmium yellow
# 4             5     phthalo green
# 4             5     prussian blue
# 4             5         sap green
# 4             5    titanium white
# 4             5    van dyke brown
# 5             6       black gesso
# 5             6     prussian blue
# 5             6    titanium white
# 5             6    van dyke brown
# 6             7  alizarin crimson
# 6             7        bright red
# 6             7    cadmium yellow
# 6             7     phthalo green
# 6             7     prussian blue
# 6             7         sap green
# 6             7    titanium white
# 6             7    van dyke brown
# 7             8  alizarin crimson
# 7             8        bright red
# 7             8    cadmium yellow
# 7             8     phthalo green
# 7             8     prussian blue
# 7             8         sap green
# 7             8    titanium white
# 7             8    van dyke brown
# 8             9  alizarin crimson
# 8             9        bright red
# 8             9    cadmium yellow
# 8             9     phthalo green
# 8             9     prussian blue
# 8             9         sap green
# 8             9    titanium white
# 8             9    van dyke brown
# 9            10  alizarin crimson
# 9            10        bright red
# 9            10    cadmium yellow
# 9            10     phthalo green
# 9            10     prussian blue
# 9            10         sap green
# 9            10    titanium white
# 9            10    van dyke brown
# 10           11  alizarin crimson
# 10           11        bright red
# 10           11    cadmium yellow
# 10           11     phthalo green
# 10           11     prussian blue
# 10           11         sap green
# 10           11    titanium white
# 10           11    van dyke brown
# 11           12  alizarin crimson
# 11           12     prussian blue
# 11           12    titanium white
# 11           12    van dyke brown
# 12           13  alizarin crimson
# 12           13        bright red
# 12           13    cadmium yellow
# 12           13     phthalo green
# 12           13     prussian blue
# 12           13         sap green
# 12           13    titanium white
# 12           13    van dyke brown
# 13           14  alizarin crimson
# 13           14        bright red
# 13           14       burnt umber
# 13           14    cadmium yellow
# 13           14     indian yellow
# 13           14      phthalo blue
# 13           14     phthalo green
# 13           14     prussian blue
# 13           14         sap green
# 13           14    titanium white
# 13           14    van dyke brown
# 13           14      yellow ochre
# 14           15  alizarin crimson
# 14           15        bright red
# 14           15       burnt umber
# 14           15    cadmium yellow
# 14           15     indian yellow
# 14           15      phthalo blue
# 14           15     phthalo green
# 14           15     prussian blue
# 14           15         sap green
# 14           15    titanium white
# 14           15    van dyke brown
# 14           15      yellow ochre
# 15           16  alizarin crimson
# 15           16       black gesso
# 15           16        bright red
# 15           16       burnt umber
# 15           16    cadmium yellow
# 15           16     indian yellow
# 15           16      phthalo blue
# 15           16     phthalo green
# 15           16     prussian blue
# 15           16         sap green
# 15           16    titanium white
# 15           16    van dyke brown
# 15           16      yellow ochre
# 16           17     prussian blue
# 16           17    titanium white
# 16           17    van dyke brown
# 17           18  alizarin crimson
# 17           18        bright red
# 17           18       burnt umber
# 17           18    cadmium yellow
# 17           18      phthalo blue
# 17           18     phthalo green
# 17           18     prussian blue
# 17           18         sap green
# 17           18    titanium white
# 17           18    van dyke brown
# 17           18      yellow ochre
# 18           19  alizarin crimson
# 18           19        bright red
# 18           19       burnt umber
# 18           19    cadmium yellow
# 18           19      phthalo blue
# 18           19     phthalo green
# 18           19     prussian blue
# 18           19         sap green
# 18           19    titanium white
# 18           19    van dyke brown
# 18           19      yellow ochre
# 19           20  alizarin crimson
# 19           20        bright red
# 19           20       burnt umber
# 19           20    cadmium yellow
# 19           20      phthalo blue
# 19           20     phthalo green
# 19           20     prussian blue
# 19           20         sap green
# 19           20    titanium white
# 19           20    van dyke brown
# 19           20      yellow ochre
# 20           21  alizarin crimson
# 20           21        bright red
# 20           21       burnt umber
# 20           21    cadmium yellow
# 20           21     indian yellow
# 20           21      phthalo blue
# 20           21     phthalo green
# 20           21     prussian blue
# 20           21         sap green
# 20           21    titanium white
# 20           21    van dyke brown
# 20           21      yellow ochre
# 21           22  alizarin crimson
# 21           22       black gesso
# 21           22        bright red
# 21           22    cadmium yellow
# 21           22     indian yellow
# 21           22      phthalo blue
# 21           22     phthalo green
# 21           22     prussian blue
# 21           22         sap green
# 21           22    titanium white
# 21           22    van dyke brown
# 21           22      yellow ochre
# 22           23  alizarin crimson
# 22           23        bright red
# 22           23       burnt umber
# 22           23    cadmium yellow
# 22           23     indian yellow
# 22           23      phthalo blue
# 22           23     phthalo green
# 22           23     prussian blue
# 22           23         sap green
# 22           23    titanium white
# 22           23    van dyke brown
# 22           23      yellow ochre
# 23           24  alizarin crimson
# 23           24       black gesso
# 23           24       burnt umber
# 23           24    cadmium yellow
# 23           24     indian yellow
# 23           24      phthalo blue
# 23           24     phthalo green
# 23           24     prussian blue
# 23           24         sap green
# 23           24    titanium white
# 23           24    van dyke brown
# 23           24      yellow ochre
# 24           25  alizarin crimson
# 24           25        bright red
# 24           25       burnt umber
# 24           25    cadmium yellow
# 24           25     indian yellow
# 24           25      phthalo blue
# 24           25     phthalo green
# 24           25     prussian blue
# 24           25         sap green
# 24           25    titanium white
# 24           25    van dyke brown
# 24           25      yellow ochre
# 25           26  alizarin crimson
# 25           26        bright red
# 25           26       burnt umber
# 25           26    cadmium yellow
# 25           26     indian yellow
# 25           26      phthalo blue
# 25           26     phthalo green
# 25           26     prussian blue
# 25           26         sap green
# 25           26    titanium white
# 25           26    van dyke brown
# 25           26      yellow ochre
# 26           27  alizarin crimson
# 26           27        bright red
# 26           27       burnt umber
# 26           27    cadmium yellow
# 26           27     indian yellow
# 26           27      phthalo blue
# 26           27     phthalo green
# 26           27     prussian blue
# 26           27         sap green
# 26           27    titanium white
# 26           27    van dyke brown
# 26           27      yellow ochre
# 27           28  alizarin crimson
# 27           28        bright red
# 27           28       burnt umber
# 27           28    cadmium yellow
# 27           28     indian yellow
# 27           28      phthalo blue
# 27           28     phthalo green
# 27           28     prussian blue
# 27           28         sap green
# 27           28    titanium white
# 27           28    van dyke brown
# 27           28      yellow ochre
# 28           29  alizarin crimson
# 28           29        bright red
# 28           29       burnt umber
# 28           29    cadmium yellow
# 28           29     indian yellow
# 28           29      phthalo blue
# 28           29     phthalo green
# 28           29     prussian blue
# 28           29         sap green
# 28           29    titanium white
# 28           29    van dyke brown
# 28           29      yellow ochre
# 29           30  alizarin crimson
# 29           30        bright red
# 29           30    cadmium yellow
# 29           30      liquid black
# 29           30     phthalo green
# 29           30    titanium white
# 29           30    van dyke brown
# 30           31  alizarin crimson
# 30           31       burnt umber
# 30           31    cadmium yellow
# 30           31         sap green
# 30           31    titanium white
# 30           31    van dyke brown
# 30           31      yellow ochre
# 31           32  alizarin crimson
# 31           32        bright red
# 31           32       burnt umber
# 31           32    cadmium yellow
# 31           32    midnight black
# 31           32     prussian blue
# 31           32         sap green
# 31           32    titanium white
# 31           32    van dyke brown
# 31           32      yellow ochre
# 32           33  alizarin crimson
# 32           33       burnt umber
# 32           33    cadmium yellow
# 32           33      phthalo blue
# 32           33     phthalo green
# 32           33     prussian blue
# 32           33         sap green
# 32           33    titanium white
# 32           33    van dyke brown
# 32           33      yellow ochre
# 33           34  alizarin crimson
# 33           34       black gesso
# 33           34       burnt umber
# 33           34    cadmium yellow
# 33           34     phthalo green
# 33           34         sap green
# 33           34    titanium white
# 33           34    van dyke brown
# 33           34      yellow ochre
# 34           35  alizarin crimson
# 34           35        bright red
# 34           35       burnt umber
# 34           35    cadmium yellow
# 34           35      phthalo blue
# 34           35     prussian blue
# 34           35         sap green
# 34           35    titanium white
# 34           35    van dyke brown
# 34           35      yellow ochre
# 35           36  alizarin crimson
# 35           36       black gesso
# 35           36        bright red
# 35           36       burnt umber
# 35           36    cadmium yellow
# 35           36     indian yellow
# 35           36    van dyke brown
# 35           36      yellow ochre
# 36           37  alizarin crimson
# 36           37        bright red
# 36           37       burnt umber
# 36           37    cadmium yellow
# 36           37     indian yellow
# 36           37      phthalo blue
# 36           37     phthalo green
# 36           37     prussian blue
# 36           37         sap green
# 36           37    titanium white
# 36           37    van dyke brown
# 36           37      yellow ochre
# 37           38  alizarin crimson
# 37           38        bright red
# 37           38       burnt umber
# 37           38    cadmium yellow
# 37           38      phthalo blue
# 37           38     prussian blue
# 37           38         sap green
# 37           38    titanium white
# 37           38    van dyke brown
# 37           38      yellow ochre
# 38           39  alizarin crimson
# 38           39    cadmium yellow
# 38           39      phthalo blue
# 38           39     phthalo green
# 38           39     prussian blue
# 38           39         sap green
# 38           39    titanium white
# 38           39    van dyke brown
# 38           39      yellow ochre
# 39           40  alizarin crimson
# 39           40      phthalo blue
# 39           40    titanium white
# 39           40    van dyke brown
# 40           41  alizarin crimson
# 40           41        bright red
# 40           41       burnt umber
# 40           41    cadmium yellow
# 40           41     indian yellow
# 40           41      phthalo blue
# 40           41         sap green
# 40           41    titanium white
# 40           41    van dyke brown
# 40           41      yellow ochre
# 41           42  alizarin crimson
# 41           42        bright red
# 41           42       burnt umber
# 41           42    cadmium yellow
# 41           42     indian yellow
# 41           42      phthalo blue
# 41           42     phthalo green
# 41           42     prussian blue
# 41           42         sap green
# 41           42    titanium white
# 41           42    van dyke brown
# 41           42      yellow ochre
# 42           43       black gesso
# 42           43        bright red
# 42           43       burnt umber
# 42           43    cadmium yellow
# 42           43    midnight black
# 42           43     prussian blue
# 42           43    titanium white
# 43           44  alizarin crimson
# 43           44       black gesso
# 43           44        bright red
# 43           44       burnt umber
# 43           44    cadmium yellow
# 43           44      phthalo blue
# 43           44     phthalo green
# 43           44     prussian blue
# 43           44    titanium white
# 43           44    van dyke brown
# 44           45  alizarin crimson
# 44           45        bright red
# 44           45       burnt umber
# 44           45    cadmium yellow
# 44           45     indian yellow
# 44           45      phthalo blue
# 44           45     prussian blue
# 44           45         sap green
# 44           45    titanium white
# 44           45    van dyke brown
# 44           45      yellow ochre
# 45           46  alizarin crimson
# 45           46        bright red
# 45           46       burnt umber
# 45           46    cadmium yellow
# 45           46     indian yellow
# 45           46      phthalo blue
# 45           46     phthalo green
# 45           46         sap green
# 45           46    titanium white
# 45           46    van dyke brown
# 45           46      yellow ochre
# 46           47  alizarin crimson
# 46           47        bright red
# 46           47       burnt umber
# 46           47    cadmium yellow
# 46           47     indian yellow
# 46           47     prussian blue
# 46           47         sap green
# 46           47    titanium white
# 46           47    van dyke brown
# 46           47      yellow ochre
# 47           48  alizarin crimson
# 47           48        bright red
# 47           48       burnt umber
# 47           48    cadmium yellow
# 47           48     indian yellow
# 47           48      phthalo blue
# 47           48     phthalo green
# 47           48     prussian blue
# 47           48         sap green
# 47           48    titanium white
# 47           48    van dyke brown
# 47           48      yellow ochre
# 48           49  alizarin crimson
# 48           49        bright red
# 48           49       burnt umber
# 48           49    cadmium yellow
# 48           49     indian yellow
# 48           49      phthalo blue
# 48           49     phthalo green
# 48           49         sap green
# 48           49    titanium white
# 48           49    van dyke brown
# 48           49      yellow ochre
# 49           50  alizarin crimson
# 49           50        bright red
# 49           50       burnt umber
# 49           50    cadmium yellow
# 49           50     indian yellow
# 49           50      liquid black
# 49           50     prussian blue
# 49           50         sap green
# 49           50    titanium white
# 49           50    van dyke brown
# 50           51  alizarin crimson
# 50           51        bright red
# 50           51       burnt umber
# 50           51    cadmium yellow
# 50           51     indian yellow
# 50           51      phthalo blue
# 50           51     phthalo green
# 50           51     prussian blue
# 50           51         sap green
# 50           51    titanium white
# 50           51    van dyke brown
# 50           51      yellow ochre
# 51           52  alizarin crimson
# 51           52    cadmium yellow
# 51           52     indian yellow
# 51           52      phthalo blue
# 51           52     phthalo green
# 51           52     prussian blue
# 51           52         sap green
# 51           52    titanium white
# 51           52    van dyke brown
# 51           52      yellow ochre
# 53           53  alizarin crimson
# 53           53       black gesso
# 53           53        bright red
# 53           53       burnt umber
# 53           53    cadmium yellow
# 53           53     indian yellow
# 53           53      phthalo blue
# 53           53     phthalo green
# 53           53         sap green
# 53           53    titanium white
# 53           53    van dyke brown
# 53           53      yellow ochre
# 54           54  alizarin crimson
# 54           54      liquid black
# 54           54      phthalo blue
# 54           54     phthalo green
# 54           54    titanium white
# 55           55  alizarin crimson
# 55           55       burnt umber
# 55           55     indian yellow
# 55           55      phthalo blue
# 55           55         sap green
# 55           55    titanium white
# 55           55    van dyke brown
# 56           56  alizarin crimson
# 56           56        bright red
# 56           56       burnt umber
# 56           56    cadmium yellow
# 56           56     indian yellow
# 56           56      phthalo blue
# 56           56         sap green
# 56           56    titanium white
# 56           56    van dyke brown
# 56           56      yellow ochre
# 57           57  alizarin crimson
# 57           57     indian yellow
# 57           57      liquid black
# 57           57     prussian blue
# 57           57    titanium white
# 57           57    van dyke brown
# 58           58  alizarin crimson
# 58           58        bright red
# 58           58       burnt umber
# 58           58    cadmium yellow
# 58           58     indian yellow
# 58           58      phthalo blue
# 58           58         sap green
# 58           58    titanium white
# 58           58    van dyke brown
# 58           58      yellow ochre
# 59           59  alizarin crimson
# 59           59       burnt umber
# 59           59    cadmium yellow
# 59           59     indian yellow
# 59           59      phthalo blue
# 59           59         sap green
# 59           59    titanium white
# 59           59    van dyke brown
# 59           59      yellow ochre
# 60           60  alizarin crimson
# 60           60    cadmium yellow
# 60           60      liquid clear
# 60           60      phthalo blue
# 60           60     phthalo green
# 60           60    titanium white
# 61           61  alizarin crimson
# 61           61       black gesso
# 61           61        bright red
# 61           61       burnt umber
# 61           61      phthalo blue
# 61           61     phthalo green
# 61           61     prussian blue
# 61           61         sap green
# 61           61    titanium white
# 61           61    van dyke brown
# 61           61      yellow ochre
# 62           62  alizarin crimson
# 62           62       burnt umber
# 62           62    cadmium yellow
# 62           62     indian yellow
# 62           62     prussian blue
# 62           62         sap green
# 62           62    titanium white
# 62           62    van dyke brown
# 63           63        bright red
# 63           63       burnt umber
# 63           63     indian yellow
# 63           63     prussian blue
# 63           63    titanium white
# 64           64  alizarin crimson
# 64           64        bright red
# 64           64       burnt umber
# 64           64    cadmium yellow
# 64           64     indian yellow
# 64           64      phthalo blue
# 64           64     phthalo green
# 64           64         sap green
# 64           64    titanium white
# 64           64    van dyke brown
# 64           64      yellow ochre
# 65           65  alizarin crimson
# 65           65       black gesso
# 65           65        bright red
# 65           65       burnt umber
# 65           65    cadmium yellow
# 65           65     indian yellow
# 65           65      phthalo blue
# 65           65     prussian blue
# 65           65         sap green
# 65           65    titanium white
# 65           65    van dyke brown
# 65           65      yellow ochre
# 66           66  alizarin crimson
# 66           66        bright red
# 66           66       burnt umber
# 66           66    cadmium yellow
# 66           66     indian yellow
# 66           66      phthalo blue
# 66           66     prussian blue
# 66           66         sap green
# 66           66    titanium white
# 66           66    van dyke brown
# 66           66      yellow ochre
# 67           67  alizarin crimson
# 67           67        bright red
# 67           67       burnt umber
# 67           67    cadmium yellow
# 67           67     indian yellow
# 67           67      phthalo blue
# 67           67         sap green
# 67           67    titanium white
# 67           67    van dyke brown
# 67           67      yellow ochre
# 68           68  alizarin crimson
# 68           68        bright red
# 68           68       burnt umber
# 68           68    cadmium yellow
# 68           68     indian yellow
# 68           68      phthalo blue
# 68           68     prussian blue
# 68           68         sap green
# 68           68    titanium white
# 68           68    van dyke brown
# 68           68      yellow ochre
# 69           69  alizarin crimson
# 69           69       black gesso
# 69           69        bright red
# 69           69       burnt umber
# 69           69    cadmium yellow
# 69           69     indian yellow
# 69           69      phthalo blue
# 69           69     phthalo green
# 69           69         sap green
# 69           69    titanium white
# 69           69    van dyke brown
# 69           69      yellow ochre
# 70           70  alizarin crimson
# 70           70       burnt umber
# 70           70    cadmium yellow
# 70           70      phthalo blue
# 70           70     phthalo green
# 70           70    titanium white
# 70           70    van dyke brown
# 70           70      yellow ochre
# 71           71  alizarin crimson
# 71           71        bright red
# 71           71       burnt umber
# 71           71    cadmium yellow
# 71           71     indian yellow
# 71           71      phthalo blue
# 71           71     phthalo green
# 71           71         sap green
# 71           71    titanium white
# 71           71    van dyke brown
# 71           71      yellow ochre
# 72           72  alizarin crimson
# 72           72        bright red
# 72           72    cadmium yellow
# 72           72     indian yellow
# 72           72     prussian blue
# 72           72    titanium white
# 72           72    van dyke brown
# 73           73  alizarin crimson
# 73           73        bright red
# 73           73       burnt umber
# 73           73    cadmium yellow
# 73           73     indian yellow
# 73           73      phthalo blue
# 73           73     phthalo green
# 73           73         sap green
# 73           73    titanium white
# 73           73    van dyke brown
# 73           73      yellow ochre
# 74           74  alizarin crimson
# 74           74        bright red
# 74           74       burnt umber
# 74           74    cadmium yellow
# 74           74     indian yellow
# 74           74     prussian blue
# 74           74         sap green
# 74           74    titanium white
# 74           74    van dyke brown
# 74           74      yellow ochre
# 75           75  alizarin crimson
# 75           75        bright red
# 75           75       burnt umber
# 75           75    cadmium yellow
# 75           75     indian yellow
# 75           75      phthalo blue
# 75           75     phthalo green
# 75           75         sap green
# 75           75    titanium white
# 75           75    van dyke brown
# 75           75      yellow ochre
# 76           76  alizarin crimson
# 76           76       black gesso
# 76           76        bright red
# 76           76       burnt umber
# 76           76    cadmium yellow
# 76           76     indian yellow
# 76           76      phthalo blue
# 76           76         sap green
# 76           76    titanium white
# 76           76    van dyke brown
# 76           76      yellow ochre
# 77           77  alizarin crimson
# 77           77        bright red
# 77           77       burnt umber
# 77           77    cadmium yellow
# 77           77     indian yellow
# 77           77      phthalo blue
# 77           77     phthalo green
# 77           77         sap green
# 77           77    titanium white
# 77           77    van dyke brown
# 77           77      yellow ochre
# 78           78        bright red
# 78           78       dark sienna
# 78           78     prussian blue
# 78           78    titanium white
# 78           78    van dyke brown
# 78           78      yellow ochre
# 79           79  alizarin crimson
# 79           79        bright red
# 79           79    cadmium yellow
# 79           79       dark sienna
# 79           79     indian yellow
# 79           79    midnight black
# 79           79      phthalo blue
# 79           79     phthalo green
# 79           79         sap green
# 79           79    titanium white
# 79           79    van dyke brown
# 79           79      yellow ochre
# 80           80  alizarin crimson
# 80           80        bright red
# 80           80    cadmium yellow
# 80           80     indian yellow
# 80           80    midnight black
# 80           80         sap green
# 80           80    titanium white
# 81           81  alizarin crimson
# 81           81        bright red
# 81           81    cadmium yellow
# 81           81       dark sienna
# 81           81     indian yellow
# 81           81    midnight black
# 81           81      phthalo blue
# 81           81     phthalo green
# 81           81         sap green
# 81           81    titanium white
# 81           81    van dyke brown
# 81           81      yellow ochre
# 82           82  alizarin crimson
# 82           82        bright red
# 82           82    cadmium yellow
# 82           82       dark sienna
# 82           82     indian yellow
# 82           82      phthalo blue
# 82           82    titanium white
# 82           82      yellow ochre
# 83           83  alizarin crimson
# 83           83        bright red
# 83           83       dark sienna
# 83           83     indian yellow
# 83           83    midnight black
# 83           83      phthalo blue
# 83           83     phthalo green
# 83           83         sap green
# 83           83    titanium white
# 83           83    van dyke brown
# 83           83      yellow ochre
# 84           84  alizarin crimson
# 84           84        bright red
# 84           84    cadmium yellow
# 84           84       dark sienna
# 84           84     indian yellow
# 84           84    midnight black
# 84           84      phthalo blue
# 84           84    titanium white
# 84           84    van dyke brown
# 84           84      yellow ochre
# 85           85  alizarin crimson
# 85           85        bright red
# 85           85    cadmium yellow
# 85           85       dark sienna
# 85           85     indian yellow
# 85           85    midnight black
# 85           85     prussian blue
# 85           85         sap green
# 85           85    titanium white
# 85           85    van dyke brown
# 85           85      yellow ochre
# 86           86  alizarin crimson
# 86           86        bright red
# 86           86    cadmium yellow
# 86           86     indian yellow
# 86           86      phthalo blue
# 86           86     phthalo green
# 86           86     prussian blue
# 86           86         sap green
# 86           86    titanium white
# 86           86    van dyke brown
# 86           86      yellow ochre
# 87           87        bright red
# 87           87    cadmium yellow
# 87           87       dark sienna
# 87           87     indian yellow
# 87           87    midnight black
# 87           87      phthalo blue
# 87           87     prussian blue
# 87           87         sap green
# 87           87    titanium white
# 87           87    van dyke brown
# 87           87      yellow ochre
# 88           88  alizarin crimson
# 88           88    midnight black
# 88           88    titanium white
# 89           89        bright red
# 89           89    cadmium yellow
# 89           89       dark sienna
# 89           89    midnight black
# 89           89      phthalo blue
# 89           89         sap green
# 89           89    titanium white
# 89           89    van dyke brown
# 89           89      yellow ochre
# 90           90  alizarin crimson
# 90           90        bright red
# 90           90    cadmium yellow
# 90           90       dark sienna
# 90           90     indian yellow
# 90           90      liquid black
# 90           90      phthalo blue
# 90           90         sap green
# 90           90    titanium white
# 90           90    van dyke brown
# 90           90      yellow ochre
# 91           91  alizarin crimson
# 91           91        bright red
# 91           91    cadmium yellow
# 91           91     indian yellow
# 91           91    midnight black
# 91           91      phthalo blue
# 91           91         sap green
# 91           91    titanium white
# 91           91    van dyke brown
# 91           91      yellow ochre
# 92           92  alizarin crimson
# 92           92        bright red
# 92           92    cadmium yellow
# 92           92       dark sienna
# 92           92     indian yellow
# 92           92    midnight black
# 92           92      phthalo blue
# 92           92     phthalo green
# 92           92         sap green
# 92           92    titanium white
# 92           92    van dyke brown
# 92           92      yellow ochre
# 93           93  alizarin crimson
# 93           93        bright red
# 93           93    cadmium yellow
# 93           93       dark sienna
# 93           93     indian yellow
# 93           93    midnight black
# 93           93      phthalo blue
# 93           93    titanium white
# 93           93    van dyke brown
# 93           93      yellow ochre
# 94           94  alizarin crimson
# 94           94        bright red
# 94           94    cadmium yellow
# 94           94       dark sienna
# 94           94     indian yellow
# 94           94    midnight black
# 94           94      phthalo blue
# 94           94         sap green
# 94           94    titanium white
# 94           94    van dyke brown
# 94           94      yellow ochre
# 95           95  alizarin crimson
# 95           95        bright red
# 95           95    cadmium yellow
# 95           95       dark sienna
# 95           95     indian yellow
# 95           95    midnight black
# 95           95     prussian blue
# 95           95         sap green
# 95           95    titanium white
# 95           95    van dyke brown
# 95           95      yellow ochre
# 96           96  alizarin crimson
# 96           96        bright red
# 96           96    cadmium yellow
# 96           96       dark sienna
# 96           96     indian yellow
# 96           96    midnight black
# 96           96      phthalo blue
# 96           96         sap green
# 96           96    titanium white
# 96           96    van dyke brown
# 96           96      yellow ochre
# 97           97  alizarin crimson
# 97           97        bright red
# 97           97    cadmium yellow
# 97           97       dark sienna
# 97           97     indian yellow
# 97           97    midnight black
# 97           97      phthalo blue
# 97           97    titanium white
# 97           97    van dyke brown
# 97           97      yellow ochre
# 98           98  alizarin crimson
# 98           98        bright red
# 98           98    cadmium yellow
# 98           98       dark sienna
# 98           98     indian yellow
# 98           98    midnight black
# 98           98      phthalo blue
# 98           98     phthalo green
# 98           98     prussian blue
# 98           98         sap green
# 98           98    titanium white
# 98           98    van dyke brown
# 98           98      yellow ochre
# 99           99  alizarin crimson
# 99           99        bright red
# 99           99    cadmium yellow
# 99           99       dark sienna
# 99           99     indian yellow
# 99           99    midnight black
# 99           99      phthalo blue
# 99           99         sap green
# 99           99    titanium white
# 99           99    van dyke brown
# 99           99      yellow ochre
# 100         100  alizarin crimson
# 100         100       black gesso
# 100         100        bright red
# 100         100    cadmium yellow
# 100         100       dark sienna
# 100         100     indian yellow
# 100         100    midnight black
# 100         100    titanium white
# 100         100    van dyke brown
# 100         100      yellow ochre
# 101         101  alizarin crimson
# 101         101        bright red
# 101         101    cadmium yellow
# 101         101     indian yellow
# 101         101      phthalo blue
# 101         101     prussian blue
# 101         101         sap green
# 101         101    titanium white
# 101         101    van dyke brown
# 101         101      yellow ochre
# 102         102  alizarin crimson
# 102         102        bright red
# 102         102    cadmium yellow
# 102         102       dark sienna
# 102         102     indian yellow
# 102         102    midnight black
# 102         102      phthalo blue
# 102         102    titanium white
# 102         102    van dyke brown
# 102         102      yellow ochre
# 103         103  alizarin crimson
# 103         103       black gesso
# 103         103        bright red
# 103         103       dark sienna
# 103         103    midnight black
# 103         103      phthalo blue
# 103         103     phthalo green
# 103         103    titanium white
# 103         103    van dyke brown
# 104         104  alizarin crimson
# 104         104        bright red
# 104         104       dark sienna
# 104         104    midnight black
# 104         104      phthalo blue
# 104         104     prussian blue
# 104         104    titanium white
# 104         104    van dyke brown
# 104         104      yellow ochre
# 105         105  alizarin crimson
# 105         105        bright red
# 105         105    cadmium yellow
# 105         105       dark sienna
# 105         105      liquid clear
# 105         105    midnight black
# 105         105      phthalo blue
# 105         105     prussian blue
# 105         105    titanium white
# 105         105    van dyke brown
# 105         105      yellow ochre
# 106         106  alizarin crimson
# 106         106       black gesso
# 106         106        bright red
# 106         106    cadmium yellow
# 106         106       dark sienna
# 106         106     indian yellow
# 106         106    midnight black
# 106         106      phthalo blue
# 106         106    titanium white
# 106         106    van dyke brown
# 106         106      yellow ochre
# 107         107  alizarin crimson
# 107         107        bright red
# 107         107    cadmium yellow
# 107         107       dark sienna
# 107         107     indian yellow
# 107         107    midnight black
# 107         107      phthalo blue
# 107         107         sap green
# 107         107    titanium white
# 107         107    van dyke brown
# 107         107      yellow ochre
# 108         108  alizarin crimson
# 108         108        bright red
# 108         108       dark sienna
# 108         108    midnight black
# 108         108      phthalo blue
# 108         108    titanium white
# 108         108    van dyke brown
# 109         109  alizarin crimson
# 109         109       black gesso
# 109         109        bright red
# 109         109    cadmium yellow
# 109         109       dark sienna
# 109         109    midnight black
# 109         109      phthalo blue
# 109         109     prussian blue
# 109         109    titanium white
# 109         109    van dyke brown
# 109         109      yellow ochre
# 110         110  alizarin crimson
# 110         110        bright red
# 110         110    cadmium yellow
# 110         110       dark sienna
# 110         110     indian yellow
# 110         110    midnight black
# 110         110      phthalo blue
# 110         110         sap green
# 110         110    titanium white
# 110         110    van dyke brown
# 110         110      yellow ochre
# 111         111  alizarin crimson
# 111         111        bright red
# 111         111    cadmium yellow
# 111         111       dark sienna
# 111         111     indian yellow
# 111         111    midnight black
# 111         111      phthalo blue
# 111         111         sap green
# 111         111    titanium white
# 111         111    van dyke brown
# 111         111      yellow ochre
# 112         112  alizarin crimson
# 112         112        bright red
# 112         112    cadmium yellow
# 112         112       dark sienna
# 112         112     indian yellow
# 112         112    midnight black
# 112         112      phthalo blue
# 112         112         sap green
# 112         112    titanium white
# 112         112    van dyke brown
# 112         112      yellow ochre
# 113         113  alizarin crimson
# 113         113        bright red
# 113         113    cadmium yellow
# 113         113       dark sienna
# 113         113     indian yellow
# 113         113    midnight black
# 113         113      phthalo blue
# 113         113         sap green
# 113         113    titanium white
# 113         113    van dyke brown
# 113         113      yellow ochre
# 114         114  alizarin crimson
# 114         114        bright red
# 114         114    cadmium yellow
# 114         114       dark sienna
# 114         114     indian yellow
# 114         114    midnight black
# 114         114      phthalo blue
# 114         114         sap green
# 114         114    titanium white
# 114         114    van dyke brown
# 114         114      yellow ochre
# 115         115  alizarin crimson
# 115         115        bright red
# 115         115    cadmium yellow
# 115         115       dark sienna
# 115         115      liquid clear
# 115         115    midnight black
# 115         115      phthalo blue
# 115         115     phthalo green
# 115         115     prussian blue
# 115         115         sap green
# 115         115    titanium white
# 115         115    van dyke brown
# 115         115      yellow ochre
# 116         116  alizarin crimson
# 116         116       black gesso
# 116         116        bright red
# 116         116    cadmium yellow
# 116         116       dark sienna
# 116         116     indian yellow
# 116         116    midnight black
# 116         116      phthalo blue
# 116         116         sap green
# 116         116    titanium white
# 116         116    van dyke brown
# 116         116      yellow ochre
# 117         117  alizarin crimson
# 117         117        bright red
# 117         117    cadmium yellow
# 117         117       dark sienna
# 117         117     indian yellow
# 117         117    midnight black
# 117         117      phthalo blue
# 117         117     phthalo green
# 117         117     prussian blue
# 117         117         sap green
# 117         117    titanium white
# 117         117    van dyke brown
# 117         117      yellow ochre
# 118         118  alizarin crimson
# 118         118        bright red
# 118         118    cadmium yellow
# 118         118       dark sienna
# 118         118     indian yellow
# 118         118    midnight black
# 118         118      phthalo blue
# 118         118     prussian blue
# 118         118         sap green
# 118         118    titanium white
# 118         118    van dyke brown
# 118         118      yellow ochre
# 119         119  alizarin crimson
# 119         119        bright red
# 119         119    cadmium yellow
# 119         119       dark sienna
# 119         119     indian yellow
# 119         119    midnight black
# 119         119      phthalo blue
# 119         119     prussian blue
# 119         119         sap green
# 119         119    titanium white
# 119         119    van dyke brown
# 119         119      yellow ochre
# 120         120  alizarin crimson
# 120         120        bright red
# 120         120    cadmium yellow
# 120         120       dark sienna
# 120         120     indian yellow
# 120         120    midnight black
# 120         120      phthalo blue
# 120         120     prussian blue
# 120         120         sap green
# 120         120    titanium white
# 120         120    van dyke brown
# 120         120      yellow ochre
# 121         121  alizarin crimson
# 121         121       black gesso
# 121         121        bright red
# 121         121    cadmium yellow
# 121         121       dark sienna
# 121         121    midnight black
# 121         121      phthalo blue
# 121         121     phthalo green
# 121         121     prussian blue
# 121         121    titanium white
# 121         121    van dyke brown
# 121         121      yellow ochre
# 122         122  alizarin crimson
# 122         122        bright red
# 122         122    cadmium yellow
# 122         122       dark sienna
# 122         122     indian yellow
# 122         122    midnight black
# 122         122      phthalo blue
# 122         122     prussian blue
# 122         122         sap green
# 122         122    titanium white
# 122         122    van dyke brown
# 122         122      yellow ochre
# 123         123  alizarin crimson
# 123         123        bright red
# 123         123       dark sienna
# 123         123    midnight black
# 123         123      phthalo blue
# 123         123    titanium white
# 123         123    van dyke brown
# 124         124  alizarin crimson
# 124         124       black gesso
# 124         124        bright red
# 124         124    cadmium yellow
# 124         124       dark sienna
# 124         124     indian yellow
# 124         124    midnight black
# 124         124      phthalo blue
# 124         124         sap green
# 124         124    titanium white
# 124         124    van dyke brown
# 124         124      yellow ochre
# 125         125        bright red
# 125         125    cadmium yellow
# 125         125       dark sienna
# 125         125     indian yellow
# 125         125    midnight black
# 125         125      phthalo blue
# 125         125     prussian blue
# 125         125         sap green
# 125         125    titanium white
# 125         125    van dyke brown
# 125         125      yellow ochre
# 126         126  alizarin crimson
# 126         126        bright red
# 126         126    cadmium yellow
# 126         126       dark sienna
# 126         126     indian yellow
# 126         126      liquid clear
# 126         126    midnight black
# 126         126      phthalo blue
# 126         126     prussian blue
# 126         126    titanium white
# 126         126    van dyke brown
# 126         126      yellow ochre
# 127         127  alizarin crimson
# 127         127        bright red
# 127         127    cadmium yellow
# 127         127       dark sienna
# 127         127     indian yellow
# 127         127    midnight black
# 127         127      phthalo blue
# 127         127     prussian blue
# 127         127         sap green
# 127         127    titanium white
# 127         127    van dyke brown
# 127         127      yellow ochre
# 128         128  alizarin crimson
# 128         128        bright red
# 128         128    cadmium yellow
# 128         128       dark sienna
# 128         128    midnight black
# 128         128      phthalo blue
# 128         128     prussian blue
# 128         128    titanium white
# 128         128    van dyke brown
# 129          92     prussian blue
# 130         129  alizarin crimson
# 130         129        bright red
# 130         129    cadmium yellow
# 130         129       dark sienna
# 130         129     indian yellow
# 130         129    midnight black
# 130         129      phthalo blue
# 130         129     prussian blue
# 130         129         sap green
# 130         129    titanium white
# 130         129    van dyke brown
# 130         129      yellow ochre
# 131         130  alizarin crimson
# 131         130        bright red
# 131         130       dark sienna
# 131         130    midnight black
# 131         130     prussian blue
# 131         130    titanium white
# 131         130    van dyke brown
# 132         131  alizarin crimson
# 132         131    cadmium yellow
# 132         131       dark sienna
# 132         131      liquid clear
# 132         131    midnight black
# 132         131      phthalo blue
# 132         131         sap green
# 132         131    titanium white
# 132         131    van dyke brown
# 132         131      yellow ochre
# 133         132  alizarin crimson
# 133         132        bright red
# 133         132    cadmium yellow
# 133         132       dark sienna
# 133         132     indian yellow
# 133         132    midnight black
# 133         132      phthalo blue
# 133         132     prussian blue
# 133         132         sap green
# 133         132    titanium white
# 133         132    van dyke brown
# 133         132      yellow ochre
# 134         133  alizarin crimson
# 134         133       black gesso
# 134         133        bright red
# 134         133    cadmium yellow
# 134         133       dark sienna
# 134         133     indian yellow
# 134         133    midnight black
# 134         133     prussian blue
# 134         133         sap green
# 134         133    titanium white
# 134         133    van dyke brown
# 134         133      yellow ochre
# 135         134        bright red
# 135         134       dark sienna
# 135         134    midnight black
# 135         134     prussian blue
# 135         134    titanium white
# 135         134    van dyke brown
# 136         135  alizarin crimson
# 136         135        bright red
# 136         135    cadmium yellow
# 136         135       dark sienna
# 136         135     indian yellow
# 136         135    midnight black
# 136         135      phthalo blue
# 136         135     prussian blue
# 136         135         sap green
# 136         135    titanium white
# 136         135    van dyke brown
# 136         135      yellow ochre
# 137         136  alizarin crimson
# 137         136        bright red
# 137         136    cadmium yellow
# 137         136       dark sienna
# 137         136     indian yellow
# 137         136    midnight black
# 137         136      phthalo blue
# 137         136         sap green
# 137         136    titanium white
# 137         136    van dyke brown
# 137         136      yellow ochre
# 138         137  alizarin crimson
# 138         137       dark sienna
# 138         137    midnight black
# 138         137      phthalo blue
# 138         137    titanium white
# 138         137    van dyke brown
# 139         138  alizarin crimson
# 139         138       black gesso
# 139         138        bright red
# 139         138    cadmium yellow
# 139         138       dark sienna
# 139         138     indian yellow
# 139         138    midnight black
# 139         138      phthalo blue
# 139         138    titanium white
# 139         138    van dyke brown
# 140         139    cadmium yellow
# 140         139       dark sienna
# 140         139     indian yellow
# 140         139      liquid clear
# 140         139     prussian blue
# 140         139    titanium white
# 140         139    van dyke brown
# 140         139      yellow ochre
# 141         140  alizarin crimson
# 141         140        bright red
# 141         140    cadmium yellow
# 141         140       dark sienna
# 141         140     indian yellow
# 141         140    midnight black
# 141         140     prussian blue
# 141         140         sap green
# 141         140    titanium white
# 141         140    van dyke brown
# 141         140      yellow ochre
# 142         141  alizarin crimson
# 142         141        bright red
# 142         141    cadmium yellow
# 142         141       dark sienna
# 142         141     indian yellow
# 142         141    midnight black
# 142         141     prussian blue
# 142         141         sap green
# 142         141    titanium white
# 142         141    van dyke brown
# 142         141      yellow ochre
# 143         142    cadmium yellow
# 143         142       dark sienna
# 143         142     indian yellow
# 143         142    midnight black
# 143         142    titanium white
# 143         142    van dyke brown
# 143         142      yellow ochre
# 144         143  alizarin crimson
# 144         143        bright red
# 144         143    cadmium yellow
# 144         143       dark sienna
# 144         143     indian yellow
# 144         143    midnight black
# 144         143      phthalo blue
# ...
# 360         359        bright red
# 360         359    cadmium yellow
# 360         359       dark sienna
# 360         359     indian yellow
# 360         359    midnight black
# 360         359      phthalo blue
# 360         359         sap green
# 360         359    titanium white
# 360         359    van dyke brown
# 360         359      yellow ochre
# 361         360  alizarin crimson
# 361         360       black gesso
# 361         360        bright red
# 361         360    cadmium yellow
# 361         360     indian yellow
# 361         360    midnight black
# 361         360      phthalo blue
# 361         360     phthalo green
# 361         360         sap green
# 361         360    titanium white
# 361         360      yellow ochre
# 362         361  alizarin crimson
# 362         361        bright red
# 362         361    cadmium yellow
# 362         361       dark sienna
# 362         361     indian yellow
# 362         361    midnight black
# 362         361      phthalo blue
# 362         361     phthalo green
# 362         361     prussian blue
# 362         361         sap green
# 362         361    titanium white
# 362         361    van dyke brown
# 362         361      yellow ochre
# 363         362  alizarin crimson
# 363         362        bright red
# 363         362    cadmium yellow
# 363         362    midnight black
# 363         362      phthalo blue
# 363         362         sap green
# 363         362    titanium white
# 363         362      yellow ochre
# 364         363  alizarin crimson
# 364         363        bright red
# 364         363    cadmium yellow
# 364         363       dark sienna
# 364         363     indian yellow
# 364         363    midnight black
# 364         363      phthalo blue
# 364         363     phthalo green
# 364         363     prussian blue
# 364         363         sap green
# 364         363    titanium white
# 364         363    van dyke brown
# 364         363      yellow ochre
# 365         364  alizarin crimson
# 365         364        bright red
# 365         364    cadmium yellow
# 365         364       dark sienna
# 365         364     indian yellow
# 365         364    midnight black
# 365         364         sap green
# 365         364    titanium white
# 365         364    van dyke brown
# 365         364      yellow ochre
# 366         365  alizarin crimson
# 366         365        bright red
# 366         365    cadmium yellow
# 366         365       dark sienna
# 366         365     indian yellow
# 366         365    midnight black
# 366         365      phthalo blue
# 366         365     phthalo green
# 366         365     prussian blue
# 366         365         sap green
# 366         365    titanium white
# 366         365    van dyke brown
# 366         365      yellow ochre
# 367         366  alizarin crimson
# 367         366       black gesso
# 367         366        bright red
# 367         366    cadmium yellow
# 367         366       dark sienna
# 367         366     indian yellow
# 367         366      liquid clear
# 367         366    midnight black
# 367         366      phthalo blue
# 367         366     prussian blue
# 367         366         sap green
# 367         366    titanium white
# 367         366    van dyke brown
# 367         366      yellow ochre
# 368         367  alizarin crimson
# 368         367        bright red
# 368         367    cadmium yellow
# 368         367       dark sienna
# 368         367     indian yellow
# 368         367    midnight black
# 368         367      phthalo blue
# 368         367     prussian blue
# 368         367         sap green
# 368         367    titanium white
# 368         367    van dyke brown
# 368         367      yellow ochre
# 369         368  alizarin crimson
# 369         368    cadmium yellow
# 369         368    midnight black
# 369         368      phthalo blue
# 369         368     phthalo green
# 369         368     prussian blue
# 369         368         sap green
# 369         368    titanium white
# 369         368    van dyke brown
# 370         369  alizarin crimson
# 370         369       black gesso
# 370         369        bright red
# 370         369    cadmium yellow
# 370         369       dark sienna
# 370         369     indian yellow
# 370         369    midnight black
# 370         369         sap green
# 370         369    titanium white
# 370         369    van dyke brown
# 370         369      yellow ochre
# 371         370  alizarin crimson
# 371         370        bright red
# 371         370    cadmium yellow
# 371         370       dark sienna
# 371         370     indian yellow
# 371         370    midnight black
# 371         370      phthalo blue
# 371         370     prussian blue
# 371         370         sap green
# 371         370    titanium white
# 371         370    van dyke brown
# 371         370      yellow ochre
# 372         371  alizarin crimson
# 372         371        bright red
# 372         371       dark sienna
# 372         371    midnight black
# 372         371      phthalo blue
# 372         371         sap green
# 372         371    titanium white
# 372         371    van dyke brown
# 372         371      yellow ochre
# 373         372  alizarin crimson
# 373         372       black gesso
# 373         372        bright red
# 373         372    midnight black
# 373         372     prussian blue
# 373         372         sap green
# 374         373  alizarin crimson
# 374         373       dark sienna
# 374         373    midnight black
# 374         373      phthalo blue
# 374         373     prussian blue
# 374         373    titanium white
# 374         373    van dyke brown
# 375         374  alizarin crimson
# 375         374       dark sienna
# 375         374      liquid clear
# 375         374    midnight black
# 375         374      phthalo blue
# 375         374     phthalo green
# 375         374     prussian blue
# 375         374    titanium white
# 375         374    van dyke brown
# 376         375  alizarin crimson
# 376         375        bright red
# 376         375    cadmium yellow
# 376         375       dark sienna
# 376         375     indian yellow
# 376         375    midnight black
# 376         375      phthalo blue
# 376         375     prussian blue
# 376         375         sap green
# 376         375    titanium white
# 376         375    van dyke brown
# 376         375      yellow ochre
# 377         376  alizarin crimson
# 377         376       black gesso
# 377         376        bright red
# 377         376    cadmium yellow
# 377         376       dark sienna
# 377         376     indian yellow
# 377         376    midnight black
# 377         376      phthalo blue
# 377         376         sap green
# 377         376    titanium white
# 377         376    van dyke brown
# 377         376      yellow ochre
# 378         377  alizarin crimson
# 378         377       black gesso
# 378         377        bright red
# 378         377    cadmium yellow
# 378         377       dark sienna
# 378         377     indian yellow
# 378         377      liquid clear
# 378         377    midnight black
# 378         377     prussian blue
# 378         377         sap green
# 378         377    titanium white
# 378         377    van dyke brown
# 378         377      yellow ochre
# 379         378  alizarin crimson
# 379         378        bright red
# 379         378       dark sienna
# 379         378     indian yellow
# 379         378    midnight black
# 379         378      phthalo blue
# 379         378     prussian blue
# 379         378    titanium white
# 379         378    van dyke brown
# 379         378      yellow ochre
# 380         379  alizarin crimson
# 380         379       black gesso
# 380         379        bright red
# 380         379    cadmium yellow
# 380         379       dark sienna
# 380         379     indian yellow
# 380         379      liquid clear
# 380         379    midnight black
# 380         379     prussian blue
# 380         379         sap green
# 380         379    titanium white
# 380         379    van dyke brown
# 380         379      yellow ochre
# 381         380  alizarin crimson
# 381         380        bright red
# 381         380    cadmium yellow
# 381         380       dark sienna
# 381         380     indian yellow
# 381         380      liquid clear
# 381         380    midnight black
# 381         380      phthalo blue
# 381         380     prussian blue
# 381         380         sap green
# 381         380    titanium white
# 381         380    van dyke brown
# 381         380      yellow ochre
# 382         381  alizarin crimson
# 382         381    cadmium yellow
# 382         381       dark sienna
# 382         381     indian yellow
# 382         381    midnight black
# 382         381     prussian blue
# 382         381         sap green
# 382         381    titanium white
# 382         381    van dyke brown
# 382         381      yellow ochre
# 383         382  alizarin crimson
# 383         382       dark sienna
# 383         382    midnight black
# 383         382      phthalo blue
# 383         382     prussian blue
# 383         382    titanium white
# 383         382    van dyke brown
# 384         383  alizarin crimson
# 384         383        bright red
# 384         383    cadmium yellow
# 384         383       dark sienna
# 384         383     indian yellow
# 384         383    midnight black
# 384         383      phthalo blue
# 384         383     phthalo green
# 384         383     prussian blue
# 384         383         sap green
# 384         383    titanium white
# 384         383    van dyke brown
# 384         383      yellow ochre
# 385         384  alizarin crimson
# 385         384        bright red
# 385         384    cadmium yellow
# 385         384       dark sienna
# 385         384    midnight black
# 385         384      phthalo blue
# 385         384     prussian blue
# 385         384         sap green
# 385         384    titanium white
# 385         384    van dyke brown
# 385         384      yellow ochre
# 386         385  alizarin crimson
# 386         385       black gesso
# 386         385    cadmium yellow
# 386         385       dark sienna
# 386         385     indian yellow
# 386         385      liquid clear
# 386         385    midnight black
# 386         385      phthalo blue
# 386         385     prussian blue
# 386         385         sap green
# 386         385    titanium white
# 386         385    van dyke brown
# 387         386  alizarin crimson
# 387         386        bright red
# 387         386    cadmium yellow
# 387         386       dark sienna
# 387         386     indian yellow
# 387         386    midnight black
# 387         386      phthalo blue
# 387         386     phthalo green
# 387         386     prussian blue
# 387         386         sap green
# 387         386    titanium white
# 387         386    van dyke brown
# 387         386      yellow ochre
# 388         387  alizarin crimson
# 388         387        bright red
# 388         387    cadmium yellow
# 388         387       dark sienna
# 388         387     indian yellow
# 388         387    midnight black
# 388         387         sap green
# 388         387    titanium white
# 388         387    van dyke brown
# 388         387      yellow ochre
# 389         388  alizarin crimson
# 389         388       black gesso
# 389         388    cadmium yellow
# 389         388       dark sienna
# 389         388     indian yellow
# 389         388    midnight black
# 389         388      phthalo blue
# 389         388     prussian blue
# 389         388         sap green
# 389         388    titanium white
# 389         388    van dyke brown
# 389         388      yellow ochre
# 390         389  alizarin crimson
# 390         389        bright red
# 390         389    cadmium yellow
# 390         389       dark sienna
# 390         389     indian yellow
# 390         389    midnight black
# 390         389      phthalo blue
# 390         389     prussian blue
# 390         389         sap green
# 390         389    titanium white
# 390         389    van dyke brown
# 390         389      yellow ochre
# 391         390  alizarin crimson
# 391         390       dark sienna
# 391         390    midnight black
# 391         390      phthalo blue
# 391         390     prussian blue
# 391         390    titanium white
# 391         390    van dyke brown
# 392         391  alizarin crimson
# 392         391        bright red
# 392         391    cadmium yellow
# 392         391       dark sienna
# 392         391     indian yellow
# 392         391      liquid black
# 392         391    midnight black
# 392         391      phthalo blue
# 392         391     prussian blue
# 392         391         sap green
# 392         391    titanium white
# 392         391    van dyke brown
# 392         391      yellow ochre
# 393         392  alizarin crimson
# 393         392        bright red
# 393         392    cadmium yellow
# 393         392       dark sienna
# 393         392     indian yellow
# 393         392    midnight black
# 393         392      phthalo blue
# 393         392         sap green
# 393         392    titanium white
# 393         392    van dyke brown
# 393         392      yellow ochre
# 394         393  alizarin crimson
# 394         393       dark sienna
# 394         393    midnight black
# 394         393      phthalo blue
# 394         393     prussian blue
# 394         393    titanium white
# 394         393    van dyke brown
# 395         394  alizarin crimson
# 395         394        bright red
# 395         394    cadmium yellow
# 395         394       dark sienna
# 395         394     indian yellow
# 395         394    midnight black
# 395         394      phthalo blue
# 395         394     phthalo green
# 395         394     prussian blue
# 395         394         sap green
# 395         394    titanium white
# 395         394    van dyke brown
# 395         394      yellow ochre
# 396         395  alizarin crimson
# 396         395        bright red
# 396         395    cadmium yellow
# 396         395       dark sienna
# 396         395     indian yellow
# 396         395    midnight black
# 396         395     prussian blue
# 396         395         sap green
# 396         395    titanium white
# 396         395    van dyke brown
# 396         395      yellow ochre
# 397         396  alizarin crimson
# 397         396       black gesso
# 397         396       dark sienna
# 397         396      liquid clear
# 397         396    midnight black
# 397         396      phthalo blue
# 397         396         sap green
# 397         396    titanium white
# 397         396    van dyke brown
# 397         396      yellow ochre
# 398         397  alizarin crimson
# 398         397        bright red
# 398         397    cadmium yellow
# 398         397       dark sienna
# 398         397     indian yellow
# 398         397      liquid black
# 398         397    midnight black
# 398         397      phthalo blue
# 398         397     phthalo green
# 398         397     prussian blue
# 398         397         sap green
# 398         397    titanium white
# 398         397    van dyke brown
# 398         397      yellow ochre
# 399         398  alizarin crimson
# 399         398       black gesso
# 399         398        bright red
# 399         398    cadmium yellow
# 399         398       dark sienna
# 399         398     indian yellow
# 399         398      liquid clear
# 399         398    midnight black
# 399         398      phthalo blue
# 399         398     phthalo green
# 399         398    titanium white
# 399         398    van dyke brown
# 399         398      yellow ochre
# 400         399  alizarin crimson
# 400         399        bright red
# 400         399    cadmium yellow
# 400         399       dark sienna
# 400         399     indian yellow
# 400         399    midnight black
# 400         399      phthalo blue
# 400         399     prussian blue
# 400         399         sap green
# 400         399    titanium white
# 400         399    van dyke brown
# 400         399      yellow ochre
# 401         400  alizarin crimson
# 401         400       dark sienna
# 401         400    midnight black
# 401         400      phthalo blue
# 401         400     prussian blue
# 401         400    titanium white
# 401         400    van dyke brown
# 402         401  alizarin crimson
# 402         401       black gesso
# 402         401        bright red
# 402         401    cadmium yellow
# 402         401       dark sienna
# 402         401     indian yellow
# 402         401    midnight black
# 402         401      phthalo blue
# 402         401         sap green
# 402         401    titanium white
# 402         401    van dyke brown
# 402         401      yellow ochre

# %%
cleaned_colors_list
# Out:
# ['alizarin crimson',
#  'black gesso',
#  'bright red',
#  'cadmium yellow',
#  'dark sienna',
#  'indian yellow',
#  'midnight black',
#  'phthalo blue',
#  'sap green',
#  'titanium white',
#  'van dyke brown',
#  'yellow ochre']

# %%
# # Prepare the SQL statement for inserting data into the Subjects table
# sql = "INSERT INTO Subjects (episode_id, color_id) VALUES (%s, %s)"

# # Convert the DataFrame to a list of tuples
# values = pc_df.to_records(index=False).tolist()

# # Execute the SQL statement to insert the data into the Subjects table
# cursor.executemany(sql, values)

# # Commit the changes to the database
# conn.commit()

# %%
cursor.close()
conn.close()
